# %% [markdown]
# Ref: https://www.kaggle.com/code/motono0223/js24-preprocessing-create-lags

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import polars as pl
import numpy as np
import gc
from matplotlib import pyplot as plt
import matplotlib.cm as cm
from sklearn.model_selection import StratifiedGroupKFold

# %% [markdown]
# # Configurations

# %%
class CONFIG:
    target_col = "responder_6"
    lag_cols_original = ["date_id", "symbol_id"] + [f"responder_{idx}" for idx in range(9)]
    lag_cols_rename = { f"responder_{idx}" : f"responder_{idx}_lag_1" for idx in range(9)}
    valid_ratio = 0.05
    start_dt = 1100

# %% [markdown]
# # Load training Data

# %%
# Use last 2 parquets
train = pl.scan_parquet(
    f"/Users/apple/Masters/Job/kaggle/jane-street-real-time-market-data-forecasting/train.parquet"
).select(
    pl.int_range(pl.len(), dtype=pl.UInt32).alias("id"),
    pl.all(),
).with_columns(
    (pl.col(CONFIG.target_col)*2).cast(pl.Int32).alias("label"),
).filter(
    pl.col("date_id").gt(CONFIG.start_dt)
)

# %% [markdown]
# # Create Lags Data from Tranining Data

# %%
lags = train.select(pl.col(CONFIG.lag_cols_original))
lags = lags.rename(CONFIG.lag_cols_rename)
lags = lags.with_columns(
    date_id = pl.col('date_id') + 1,  # lagged by 1 day
    )
lags = lags.group_by(["date_id", "symbol_id"], maintain_order=True).last()  # pick up last record of previous date
lags
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="2507pt" height="578pt"
#  viewBox="0.00 0.00 2507.25 578.25" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 574.25)">
# <title>polars_query</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-574.25 2503.25,-574.25 2503.25,4 -4,4"/>
# <!-- p2 -->
# <g id="node1" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="1418.5,-474.5 1080.75,-474.5 1080.75,-438.5 1418.5,-438.5 1418.5,-474.5"/>
# <text text-anchor="middle" x="1249.62" y="-451.82" font-family="Monospace" font-size="14.00">WITH COLUMNS [[(col(&quot;date_id&quot;)) + (1)]]</text>
# </g>
# <!-- p1 -->
# <g id="node2" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="2499.25,-570.25 0,-570.25 0,-510.5 2499.25,-510.5 2499.25,-570.25"/>
# <text text-anchor="middle" x="1249.62" y="-552.95" font-family="Monospace" font-size="14.00">AGG [col(&quot;responder_0_lag_1&quot;).last(), col(&quot;responder_1_lag_1&quot;).last(), col(&quot;responder_2_lag_1&quot;).last(), col(&quot;responder_3_lag_1&quot;).last(), col(&quot;responder_4_lag_1&quot;).last(), col(&quot;responder_5_lag_1&quot;).last(), col(&quot;responder_6_lag_1&quot;).last(), col(&quot;responder_7_lag_1&quot;).last(), col(&quot;responder_8_lag_1&quot;).last()]</text>
# <text text-anchor="middle" x="1249.62" y="-535.7" font-family="Monospace" font-size="14.00">BY</text>
# <text text-anchor="middle" x="1249.62" y="-518.45" font-family="Monospace" font-size="14.00">[col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p2&#45;&gt;p1 -->
# <g id="edge1" class="edge">
# <title>p2&#45;&gt;p1</title>
# <path fill="none" stroke="black" d="M1249.62,-474.86C1249.62,-481.9 1249.62,-490.34 1249.62,-498.77"/>
# <polygon fill="black" stroke="black" points="1246.13,-498.6 1249.63,-508.6 1253.13,-498.6 1246.13,-498.6"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="1286.5,-402.5 1212.75,-402.5 1212.75,-366.5 1286.5,-366.5 1286.5,-402.5"/>
# <text text-anchor="middle" x="1249.62" y="-379.82" font-family="Monospace" font-size="14.00">π 11/11</text>
# </g>
# <!-- p3&#45;&gt;p2 -->
# <g id="edge2" class="edge">
# <title>p3&#45;&gt;p2</title>
# <path fill="none" stroke="black" d="M1249.62,-402.8C1249.62,-410.09 1249.62,-418.77 1249.62,-426.96"/>
# <polygon fill="black" stroke="black" points="1246.13,-426.88 1249.63,-436.88 1253.13,-426.88 1246.13,-426.88"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="1286.5,-330.5 1212.75,-330.5 1212.75,-294.5 1286.5,-294.5 1286.5,-330.5"/>
# <text text-anchor="middle" x="1249.62" y="-307.82" font-family="Monospace" font-size="14.00">π 11/11</text>
# </g>
# <!-- p4&#45;&gt;p3 -->
# <g id="edge3" class="edge">
# <title>p4&#45;&gt;p3</title>
# <path fill="none" stroke="black" d="M1249.62,-330.8C1249.62,-338.09 1249.62,-346.77 1249.62,-354.96"/>
# <polygon fill="black" stroke="black" points="1246.13,-354.88 1249.63,-364.88 1253.13,-354.88 1246.13,-354.88"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="1410.25,-258.5 1089,-258.5 1089,-222.5 1410.25,-222.5 1410.25,-258.5"/>
# <text text-anchor="middle" x="1249.62" y="-235.82" font-family="Monospace" font-size="14.00">FILTER BY [(col(&quot;date_id&quot;)) &gt; (1100)]</text>
# </g>
# <!-- p5&#45;&gt;p4 -->
# <g id="edge4" class="edge">
# <title>p5&#45;&gt;p4</title>
# <path fill="none" stroke="black" d="M1249.62,-258.8C1249.62,-266.09 1249.62,-274.77 1249.62,-282.96"/>
# <polygon fill="black" stroke="black" points="1246.13,-282.88 1249.63,-292.88 1253.13,-282.88 1246.13,-282.88"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="1583.5,-186.5 915.75,-186.5 915.75,-150.5 1583.5,-150.5 1583.5,-186.5"/>
# <text text-anchor="middle" x="1249.62" y="-163.82" font-family="Monospace" font-size="14.00">WITH COLUMNS [[(col(&quot;responder_6&quot;)) * (2.0)].strict_cast(Int32).alias(&quot;label&quot;)]</text>
# </g>
# <!-- p6&#45;&gt;p5 -->
# <g id="edge5" class="edge">
# <title>p6&#45;&gt;p5</title>
# <path fill="none" stroke="black" d="M1249.62,-186.8C1249.62,-194.09 1249.62,-202.77 1249.62,-210.96"/>
# <polygon fill="black" stroke="black" points="1246.13,-210.88 1249.63,-220.88 1253.13,-210.88 1246.13,-210.88"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="1286.5,-114.5 1212.75,-114.5 1212.75,-78.5 1286.5,-78.5 1286.5,-114.5"/>
# <text text-anchor="middle" x="1249.62" y="-91.83" font-family="Monospace" font-size="14.00">π 94/94</text>
# </g>
# <!-- p7&#45;&gt;p6 -->
# <g id="edge6" class="edge">
# <title>p7&#45;&gt;p6</title>
# <path fill="none" stroke="black" d="M1249.62,-114.8C1249.62,-122.09 1249.62,-130.77 1249.62,-138.96"/>
# <polygon fill="black" stroke="black" points="1246.13,-138.88 1249.63,-148.88 1253.13,-138.88 1246.13,-138.88"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="1905.25,-42.5 594,-42.5 594,0 1905.25,0 1905.25,-42.5"/>
# <text text-anchor="middle" x="1249.62" y="-25.2" font-family="Monospace" font-size="14.00">Parquet SCAN [/Users/apple/Masters/Job/kaggle/jane&#45;street&#45;real&#45;time&#45;market&#45;data&#45;forecasting/train.parquet/partition_id=0/part&#45;0.parquet, ... 9 other sources]</text>
# <text text-anchor="middle" x="1249.62" y="-7.95" font-family="Monospace" font-size="14.00">π */93;</text>
# </g>
# <!-- p8&#45;&gt;p7 -->
# <g id="edge7" class="edge">
# <title>p8&#45;&gt;p7</title>
# <path fill="none" stroke="black" d="M1249.62,-42.65C1249.62,-50.16 1249.62,-58.81 1249.62,-66.91"/>
# <polygon fill="black" stroke="black" points="1246.13,-66.67 1249.63,-76.67 1253.13,-66.67 1246.13,-66.67"/>
# </g>
# </g>
# </svg>

# %% [markdown]
# # Merge Training Data nad Lags Data

# %%
train = train.join(lags, on=["date_id", "symbol_id"],  how="left")
train
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="5074pt" height="783pt"
#  viewBox="0.00 0.00 5074.25 782.75" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 778.75)">
# <title>polars_query</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-778.75 5070.25,-778.75 5070.25,4 -4,4"/>
# <!-- p2 -->
# <g id="node1" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="2871.75,-679 2517.5,-679 2517.5,-619.25 2871.75,-619.25 2871.75,-679"/>
# <text text-anchor="middle" x="2694.62" y="-661.7" font-family="Monospace" font-size="14.00">JOIN LEFT</text>
# <text text-anchor="middle" x="2694.62" y="-644.45" font-family="Monospace" font-size="14.00">left: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)];</text>
# <text text-anchor="middle" x="2694.62" y="-627.2" font-family="Monospace" font-size="14.00">right: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p1 -->
# <g id="node2" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="2148.75,-774.75 1794.5,-774.75 1794.5,-715 2148.75,-715 2148.75,-774.75"/>
# <text text-anchor="middle" x="1971.62" y="-757.45" font-family="Monospace" font-size="14.00">JOIN LEFT</text>
# <text text-anchor="middle" x="1971.62" y="-740.2" font-family="Monospace" font-size="14.00">left: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)];</text>
# <text text-anchor="middle" x="1971.62" y="-722.95" font-family="Monospace" font-size="14.00">right: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p2&#45;&gt;p1 -->
# <g id="edge1" class="edge">
# <title>p2&#45;&gt;p1</title>
# <path fill="none" stroke="black" d="M2517.44,-677.77C2514.48,-678.19 2511.54,-678.6 2508.62,-679 2393.07,-694.95 2263.21,-710.69 2160.14,-722.68"/>
# <polygon fill="black" stroke="black" points="2160.02,-719.17 2150.49,-723.8 2160.83,-726.12 2160.02,-719.17"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="2549.25,-571.38 2228,-571.38 2228,-535.38 2549.25,-535.38 2549.25,-571.38"/>
# <text text-anchor="middle" x="2388.62" y="-548.7" font-family="Monospace" font-size="14.00">FILTER BY [(col(&quot;date_id&quot;)) &gt; (1100)]</text>
# </g>
# <!-- p3&#45;&gt;p2 -->
# <g id="edge2" class="edge">
# <title>p3&#45;&gt;p2</title>
# <path fill="none" stroke="black" d="M2445.46,-571.79C2485.47,-584.05 2540.24,-600.83 2588.24,-615.53"/>
# <polygon fill="black" stroke="black" points="2586.97,-618.8 2597.56,-618.39 2589.02,-612.11 2586.97,-618.8"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="2722.5,-487.5 2054.75,-487.5 2054.75,-451.5 2722.5,-451.5 2722.5,-487.5"/>
# <text text-anchor="middle" x="2388.62" y="-464.82" font-family="Monospace" font-size="14.00">WITH COLUMNS [[(col(&quot;responder_6&quot;)) * (2.0)].strict_cast(Int32).alias(&quot;label&quot;)]</text>
# </g>
# <!-- p4&#45;&gt;p3 -->
# <g id="edge3" class="edge">
# <title>p4&#45;&gt;p3</title>
# <path fill="none" stroke="black" d="M2388.62,-487.86C2388.62,-498.28 2388.62,-511.8 2388.62,-523.76"/>
# <polygon fill="black" stroke="black" points="2385.13,-523.52 2388.63,-533.52 2392.13,-523.52 2385.13,-523.52"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="2425.5,-415.5 2351.75,-415.5 2351.75,-379.5 2425.5,-379.5 2425.5,-415.5"/>
# <text text-anchor="middle" x="2388.62" y="-392.82" font-family="Monospace" font-size="14.00">π 94/94</text>
# </g>
# <!-- p5&#45;&gt;p4 -->
# <g id="edge4" class="edge">
# <title>p5&#45;&gt;p4</title>
# <path fill="none" stroke="black" d="M2388.62,-415.8C2388.62,-423.09 2388.62,-431.77 2388.62,-439.96"/>
# <polygon fill="black" stroke="black" points="2385.13,-439.88 2388.63,-449.88 2392.13,-439.88 2385.13,-439.88"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="3044.25,-343.5 1733,-343.5 1733,-301 3044.25,-301 3044.25,-343.5"/>
# <text text-anchor="middle" x="2388.62" y="-326.2" font-family="Monospace" font-size="14.00">Parquet SCAN [/Users/apple/Masters/Job/kaggle/jane&#45;street&#45;real&#45;time&#45;market&#45;data&#45;forecasting/train.parquet/partition_id=0/part&#45;0.parquet, ... 9 other sources]</text>
# <text text-anchor="middle" x="2388.62" y="-308.95" font-family="Monospace" font-size="14.00">π */93;</text>
# </g>
# <!-- p6&#45;&gt;p5 -->
# <g id="edge5" class="edge">
# <title>p6&#45;&gt;p5</title>
# <path fill="none" stroke="black" d="M2388.62,-343.65C2388.62,-351.16 2388.62,-359.81 2388.62,-367.91"/>
# <polygon fill="black" stroke="black" points="2385.13,-367.67 2388.63,-377.67 2392.13,-367.67 2385.13,-367.67"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="5066.25,-583.25 2567,-583.25 2567,-523.5 5066.25,-523.5 5066.25,-583.25"/>
# <text text-anchor="middle" x="3816.62" y="-565.95" font-family="Monospace" font-size="14.00">AGG [col(&quot;responder_0_lag_1&quot;).last(), col(&quot;responder_1_lag_1&quot;).last(), col(&quot;responder_2_lag_1&quot;).last(), col(&quot;responder_3_lag_1&quot;).last(), col(&quot;responder_4_lag_1&quot;).last(), col(&quot;responder_5_lag_1&quot;).last(), col(&quot;responder_6_lag_1&quot;).last(), col(&quot;responder_7_lag_1&quot;).last(), col(&quot;responder_8_lag_1&quot;).last()]</text>
# <text text-anchor="middle" x="3816.62" y="-548.7" font-family="Monospace" font-size="14.00">BY</text>
# <text text-anchor="middle" x="3816.62" y="-531.45" font-family="Monospace" font-size="14.00">[col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p7&#45;&gt;p2 -->
# <g id="edge6" class="edge">
# <title>p7&#45;&gt;p2</title>
# <path fill="none" stroke="black" d="M3465.08,-583.75C3272.7,-599.82 3041.94,-619.1 2883.42,-632.35"/>
# <polygon fill="black" stroke="black" points="2883.32,-628.85 2873.64,-633.17 2883.9,-635.82 2883.32,-628.85"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="3985.5,-487.5 3647.75,-487.5 3647.75,-451.5 3985.5,-451.5 3985.5,-487.5"/>
# <text text-anchor="middle" x="3816.62" y="-464.82" font-family="Monospace" font-size="14.00">WITH COLUMNS [[(col(&quot;date_id&quot;)) + (1)]]</text>
# </g>
# <!-- p8&#45;&gt;p7 -->
# <g id="edge7" class="edge">
# <title>p8&#45;&gt;p7</title>
# <path fill="none" stroke="black" d="M3816.62,-487.86C3816.62,-494.9 3816.62,-503.34 3816.62,-511.77"/>
# <polygon fill="black" stroke="black" points="3813.13,-511.6 3816.63,-521.6 3820.13,-511.6 3813.13,-511.6"/>
# </g>
# <!-- p9 -->
# <g id="node9" class="node">
# <title>p9</title>
# <polygon fill="none" stroke="black" points="3853.5,-415.5 3779.75,-415.5 3779.75,-379.5 3853.5,-379.5 3853.5,-415.5"/>
# <text text-anchor="middle" x="3816.62" y="-392.82" font-family="Monospace" font-size="14.00">π 11/11</text>
# </g>
# <!-- p9&#45;&gt;p8 -->
# <g id="edge8" class="edge">
# <title>p9&#45;&gt;p8</title>
# <path fill="none" stroke="black" d="M3816.62,-415.8C3816.62,-423.09 3816.62,-431.77 3816.62,-439.96"/>
# <polygon fill="black" stroke="black" points="3813.13,-439.88 3816.63,-449.88 3820.13,-439.88 3813.13,-439.88"/>
# </g>
# <!-- p10 -->
# <g id="node10" class="node">
# <title>p10</title>
# <polygon fill="none" stroke="black" points="3853.5,-340.25 3779.75,-340.25 3779.75,-304.25 3853.5,-304.25 3853.5,-340.25"/>
# <text text-anchor="middle" x="3816.62" y="-317.57" font-family="Monospace" font-size="14.00">π 11/11</text>
# </g>
# <!-- p10&#45;&gt;p9 -->
# <g id="edge9" class="edge">
# <title>p10&#45;&gt;p9</title>
# <path fill="none" stroke="black" d="M3816.62,-340.61C3816.62,-348.67 3816.62,-358.47 3816.62,-367.6"/>
# <polygon fill="black"

# %% [markdown]
# # Split Training Data and Validation Data

# %%
len_train   = train.select(pl.col("date_id")).collect().shape[0]
valid_records = int(len_train * CONFIG.valid_ratio)
len_ofl_mdl = len_train - valid_records
last_tr_dt  = train.select(pl.col("date_id")).collect().row(len_ofl_mdl)[0]

print(f"\n len_train = {len_train}")
print(f"\n len_ofl_mdl = {len_ofl_mdl}")
print(f"\n---> Last offline train date = {last_tr_dt}\n")

training_data = train.filter(pl.col("date_id").le(last_tr_dt))
validation_data   = train.filter(pl.col("date_id").gt(last_tr_dt))
# Out:
#  len_train = 22104280
#
#  len_ofl_mdl = 20999066
#
# ---> Last offline train date = 1669

# %%
validation_data
# Out:
# <h4>NAIVE QUERY PLAN</h4><p>run <b>LazyFrame.show_graph()</b> to see the optimized version</p><?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 12.2.1 (20241206.2353)
#  -->
# <!-- Title: polars_query Pages: 1 -->
# <svg width="4782pt" height="855pt"
#  viewBox="0.00 0.00 4782.25 854.75" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 850.75)">
# <title>polars_query</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-850.75 4778.25,-850.75 4778.25,4 -4,4"/>
# <!-- p2 -->
# <g id="node1" class="node">
# <title>p2</title>
# <polygon fill="none" stroke="black" points="2978.75,-774.75 2624.5,-774.75 2624.5,-715 2978.75,-715 2978.75,-774.75"/>
# <text text-anchor="middle" x="2801.62" y="-757.45" font-family="Monospace" font-size="14.00">JOIN LEFT</text>
# <text text-anchor="middle" x="2801.62" y="-740.2" font-family="Monospace" font-size="14.00">left: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)];</text>
# <text text-anchor="middle" x="2801.62" y="-722.95" font-family="Monospace" font-size="14.00">right: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p1 -->
# <g id="node2" class="node">
# <title>p1</title>
# <polygon fill="none" stroke="black" points="2962.25,-846.75 2641,-846.75 2641,-810.75 2962.25,-810.75 2962.25,-846.75"/>
# <text text-anchor="middle" x="2801.62" y="-824.08" font-family="Monospace" font-size="14.00">FILTER BY [(col(&quot;date_id&quot;)) &gt; (1669)]</text>
# </g>
# <!-- p2&#45;&gt;p1 -->
# <g id="edge1" class="edge">
# <title>p2&#45;&gt;p1</title>
# <path fill="none" stroke="black" d="M2801.62,-774.97C2801.62,-782.91 2801.62,-791.49 2801.62,-799.39"/>
# <polygon fill="black" stroke="black" points="2798.13,-799.15 2801.63,-809.15 2805.13,-799.15 2798.13,-799.15"/>
# </g>
# <!-- p3 -->
# <g id="node3" class="node">
# <title>p3</title>
# <polygon fill="none" stroke="black" points="2256.75,-679 1902.5,-679 1902.5,-619.25 2256.75,-619.25 2256.75,-679"/>
# <text text-anchor="middle" x="2079.62" y="-661.7" font-family="Monospace" font-size="14.00">JOIN LEFT</text>
# <text text-anchor="middle" x="2079.62" y="-644.45" font-family="Monospace" font-size="14.00">left: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)];</text>
# <text text-anchor="middle" x="2079.62" y="-627.2" font-family="Monospace" font-size="14.00">right: [col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p3&#45;&gt;p2 -->
# <g id="edge2" class="edge">
# <title>p3&#45;&gt;p2</title>
# <path fill="none" stroke="black" d="M2256.82,-677.77C2259.77,-678.19 2262.71,-678.6 2265.62,-679 2380.86,-694.91 2510.33,-710.64 2613.16,-722.63"/>
# <polygon fill="black" stroke="black" points="2612.45,-726.07 2622.79,-723.75 2613.26,-719.12 2612.45,-726.07"/>
# </g>
# <!-- p4 -->
# <g id="node4" class="node">
# <title>p4</title>
# <polygon fill="none" stroke="black" points="816.25,-571.38 495,-571.38 495,-535.38 816.25,-535.38 816.25,-571.38"/>
# <text text-anchor="middle" x="655.62" y="-548.7" font-family="Monospace" font-size="14.00">FILTER BY [(col(&quot;date_id&quot;)) &gt; (1100)]</text>
# </g>
# <!-- p4&#45;&gt;p3 -->
# <g id="edge3" class="edge">
# <title>p4&#45;&gt;p3</title>
# <path fill="none" stroke="black" d="M746.12,-571.86C771.44,-576.2 799.03,-580.41 824.62,-583.25 1201.43,-625.03 1644.93,-639.98 1890.97,-645.28"/>
# <polygon fill="black" stroke="black" points="1890.59,-648.77 1900.66,-645.48 1890.74,-641.77 1890.59,-648.77"/>
# </g>
# <!-- p5 -->
# <g id="node5" class="node">
# <title>p5</title>
# <polygon fill="none" stroke="black" points="989.5,-487.5 321.75,-487.5 321.75,-451.5 989.5,-451.5 989.5,-487.5"/>
# <text text-anchor="middle" x="655.62" y="-464.82" font-family="Monospace" font-size="14.00">WITH COLUMNS [[(col(&quot;responder_6&quot;)) * (2.0)].strict_cast(Int32).alias(&quot;label&quot;)]</text>
# </g>
# <!-- p5&#45;&gt;p4 -->
# <g id="edge4" class="edge">
# <title>p5&#45;&gt;p4</title>
# <path fill="none" stroke="black" d="M655.62,-487.86C655.62,-498.28 655.62,-511.8 655.62,-523.76"/>
# <polygon fill="black" stroke="black" points="652.13,-523.52 655.63,-533.52 659.13,-523.52 652.13,-523.52"/>
# </g>
# <!-- p6 -->
# <g id="node6" class="node">
# <title>p6</title>
# <polygon fill="none" stroke="black" points="692.5,-415.5 618.75,-415.5 618.75,-379.5 692.5,-379.5 692.5,-415.5"/>
# <text text-anchor="middle" x="655.62" y="-392.82" font-family="Monospace" font-size="14.00">π 94/94</text>
# </g>
# <!-- p6&#45;&gt;p5 -->
# <g id="edge5" class="edge">
# <title>p6&#45;&gt;p5</title>
# <path fill="none" stroke="black" d="M655.62,-415.8C655.62,-423.09 655.62,-431.77 655.62,-439.96"/>
# <polygon fill="black" stroke="black" points="652.13,-439.88 655.63,-449.88 659.13,-439.88 652.13,-439.88"/>
# </g>
# <!-- p7 -->
# <g id="node7" class="node">
# <title>p7</title>
# <polygon fill="none" stroke="black" points="1311.25,-343.5 0,-343.5 0,-301 1311.25,-301 1311.25,-343.5"/>
# <text text-anchor="middle" x="655.62" y="-326.2" font-family="Monospace" font-size="14.00">Parquet SCAN [/Users/apple/Masters/Job/kaggle/jane&#45;street&#45;real&#45;time&#45;market&#45;data&#45;forecasting/train.parquet/partition_id=0/part&#45;0.parquet, ... 9 other sources]</text>
# <text text-anchor="middle" x="655.62" y="-308.95" font-family="Monospace" font-size="14.00">π */93;</text>
# </g>
# <!-- p7&#45;&gt;p6 -->
# <g id="edge6" class="edge">
# <title>p7&#45;&gt;p6</title>
# <path fill="none" stroke="black" d="M655.62,-343.65C655.62,-351.16 655.62,-359.81 655.62,-367.91"/>
# <polygon fill="black" stroke="black" points="652.13,-367.67 655.63,-377.67 659.13,-367.67 652.13,-367.67"/>
# </g>
# <!-- p8 -->
# <g id="node8" class="node">
# <title>p8</title>
# <polygon fill="none" stroke="black" points="3333.25,-583.25 834,-583.25 834,-523.5 3333.25,-523.5 3333.25,-583.25"/>
# <text text-anchor="middle" x="2083.62" y="-565.95" font-family="Monospace" font-size="14.00">AGG [col(&quot;responder_0_lag_1&quot;).last(), col(&quot;responder_1_lag_1&quot;).last(), col(&quot;responder_2_lag_1&quot;).last(), col(&quot;responder_3_lag_1&quot;).last(), col(&quot;responder_4_lag_1&quot;).last(), col(&quot;responder_5_lag_1&quot;).last(), col(&quot;responder_6_lag_1&quot;).last(), col(&quot;responder_7_lag_1&quot;).last(), col(&quot;responder_8_lag_1&quot;).last()]</text>
# <text text-anchor="middle" x="2083.62" y="-548.7" font-family="Monospace" font-size="14.00">BY</text>
# <text text-anchor="middle" x="2083.62" y="-531.45" font-family="Monospace" font-size="14.00">[col(&quot;date_id&quot;), col(&quot;symbol_id&quot;)]</text>
# </g>
# <!-- p8&#45;&gt;p3 -->
# <g id="edge7" class="edge">
# <title>p8&#45;&gt;p3</title>
# <path fill="none" stroke="black" d="M2082.38,-583.52C2082.05,-591.2 2081.69,-599.61 2081.35,-607.76"/>
# <polygon fill="black" stroke="black" points="2077.86,-607.34 2080.93,-617.48 2084.86,-607.64 2077.86,-607.34"/>
# </g>
# <!-- p9 -->
# <g id="node9" class="node">
# <title>p9</title>
# <polygon fill="none" stroke="black" points="2252.5,-487.5 1914.75,-487.5 1914.75,-451.5 2252.5,-451.5 2252.5,-487.5"/>
# <text text-anchor="middle" x="2083.62" y="-464.82" font-family="Monospace" font-size="14.00">WITH COLUMNS [[(col(&quot;date_id&quot;)) + (1)]]</text>
# </g>
# <!-- p9&#45;&gt;p8 -->
# <g id="edge8" class="edge">
# <title>p9&#45;&gt;p8</title>
# <path fill="none" stroke="black" d="M2083.62,-487.86C2083.62,-494.9 2083.62,-503.34 2083.62,-511.77"/>
# <polygon fill="black" stroke="black" points="2080.13,-511.6 2083.63,-521.6 2087.13,-511.6 2080.13,-511.6"/>
# </g>
# <!-- p10 -->
# <g id="node10" class="node">
# <title>p10</title>
# <polygon fill="none" stroke="black" points="2120.5,-415.5 2046.75,-415.5 2046.75,-379.5 2120.5,-379.5 2120.5,-415.5"/>
# <text text-anchor="middle" x="2083.62" y="-392.82" font-family="Monospace" font-size="14.00">π 11/11</text>
# </g>
# <!-- p10&#45;&gt;p9 -->
# <g id="edge9" class="edge">
# <title>p10&#45;&gt;p9</title>
# <path fill="none" stroke="black" d="M2083.62,-415.8C2083.62,-423.09 2083.62,-431.77 208

# %%
training_data.collect().\
write_parquet(
    f"training.parquet", partition_by = "date_id",
)

# %%
validation_data.collect().\
write_parquet(
    "validation.parquet", partition_by = "date_id",
)
